# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

import requests
from bs4 import BeautifulSoup
import os
import shutil
import time

# Tarayıcıyı başlatma
driver = webdriver.Chrome()

# Hava durumu web sitesi açılıyor
driver.get("https://www.timeanddate.com/weather/")
time.sleep(3)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
print(soup)
# Out:
# <html lang="en" style="--site-header-offset: 150px;"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>World Temperatures — Weather Around The World</title><meta content="Weather forecast &amp; current weather worldwide in Fahrenheit or Celsius - hour-by-hour &amp; 2 week forecast plus last week's weather." name="description"/><meta content="max-image-preview:large" name="robots"/><meta content="https://www.timeanddate.com/scripts/weather_og.php?h1=Weather&amp;h2=Local%20Weather%20Around%20the%20World" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="website" property="og:type"/><style>
# ...

# %%
td_tags = soup.find_all('td')

# Şehir ve ülke isimlerini saklayacağımız listeler
city_list = []
country_list = []

for td in td_tags:
    a_tag = td.find('a', href=True)

    if a_tag:
        href = a_tag['href']  # href metni al
        # href formatı: /weather/ülke/sehir şeklinde olduğu için parçalama yapıyoruz
        parts = href.split('/')
        if len(parts) == 4:
            country = parts[2]  # ülke ismi
            city = parts[3].replace('-', ' ').title()  # şehir ismi, '-' işaretlerini boşluk ile değiştirip title case yapıyoruz
            country_list.append(country)
            city_list.append(city)
#print("Ülke Listesi:", country_list)
#print("Şehir Listesi:", city_list)

# %%
matched_list = []
id = 1

for country, city in zip(country_list, city_list):
    matched_list.append((id, country.title(), city.title()))
    id += 1

for entry in matched_list:
    print(f" id: {entry[0]}, Country: {entry[1]}, City: {entry[2]}")
# Out:
#  id: 1, Country: Ghana, City: Accra
#  id: 2, Country: Ireland, City: Dublin
#  id: 3, Country: Kenya, City: Nairobi
#  id: 4, Country: Ethiopia, City: Addis Ababa
#  id: 5, Country: Canada, City: Edmonton
#  id: 6, Country: Bahamas, City: Nassau
#  id: 7, Country: Australia, City: Adelaide
#  id: 8, Country: Germany, City: Frankfurt
#  id: 9, Country: India, City: New Delhi
#  id: 10, Country: Algeria, City: Algiers
#  id: 11, Country: Guatemala, City: Guatemala
#  id: 12, Country: Usa, City: New Orleans
#  id: 13, Country: Kazakstan, City: Almaty
#  id: 14, Country: Canada, City: Halifax
#  id: 15, Country: Usa, City: New York
#  id: 16, Country: Jordan, City: Amman
#  id: 17, Country: Vietnam, City: Hanoi
#  id: 18, Country: Norway, City: Oslo
#  id: 19, Country: Netherlands, City: Amsterdam
#  id: 20, Country: Zimbabwe, City: Harare
#  id: 21, Country: Canada, City: Ottawa
#  id: 22, Country: Russia, City: Anadyr
#  id: 23, Country: Cuba, City: Havana
# ...

# %%
#ilk = soup.find_all('td')

# %%
rbi_class = []
rbi_c = soup.find_all('td', class_='rbi')


for td in rbi_c:
    temp_text = td.get_text(strip=True).replace('°C', '')  # '°C' sembolünü kaldır ve boşlukları temizle
    rbi_class.append(int(temp_text))  # Değeri float tipine dönüştür ve listeye ekle

# Listeyi yazdır
print(rbi_class)
# Out:
# [28, 14, 24, 22, 5, 24, 15, 22, 35, 24, 17, 28, 27, 7, 17, 26, 27, 12, 21, 21, 12, 5, 23, 18, 4, 11, 20, 19, 26, 18, 28, 26, 25, 26, 26, 17, 26, 19, 9, 21, 32, 23, 15, 21, 39, 40, 33, 22, 30, 22, 16, 20, 6, 13, 22, 34, 27, 29, 31, 23, 21, 28, 8, 29, 27, 27, 22, 26, 19, 11, 35, 14, 14, 33, 21, 18, 42, 23, 20, 23, 31, 20, 2, 16, 24, 29, 9, 22, 37, 14, 18, 24, 24, 30, 16, 19, 6, 20, 25, 11, 18, 12, 24, 18, 29, 28, 20, 20, 25, 23, 31, 24, 29, 25, 20, 16, 16, 26, 16, 12, 21, 25, 20, 30, 14, 22, 8, 20, 21, 18, 17, 10, 36, 13, 27, 38, 13, 20, 40, 32, 15]

# %%
#primary_key = 1

# text
"""
with open('list_of_country.txt', 'w') as file:
    for country, city, temp in zip(country_list, city_list, rbi_class):
        file.write(f"Primary Key: {primary_key}, Country: {country.title()}, City: {city.title()}, Temp: {temp}°C\n")
        primary_key += 1

print("Succsesful")
"""
# Out:
# '\nwith open(\'list_of_country.txt\', \'w\') as file:\n    for country, city, temp in zip(country_list, city_list, rbi_class):\n        file.write(f"Primary Key: {primary_key}, Country: {country.title()}, City: {city.title()}, Temp: {temp}°C\n")\n        primary_key += 1\n\nprint("Succsesful")\n'

# %%
len(rbi_class)
# Out:
# 141

# %%
date = soup.find_all('td', class_='r')

# Gün ve saat bilgilerini listeye ekle
date_list = []

for tag in date:
    if tag.get_text(strip=True):  # Eğer <td> etiketi metin içeriyorsa (resim gibi boş değilse)
        date_list.append(tag.get_text(strip=True))
print(date_list)
len(date_list)
# Out:
# ['Sun 10:51', 'Sun 11:51', 'Sun 13:51', 'Sun 13:51', 'Sun 04:51', 'Sun 06:51', 'Sun 20:21', 'Sun 12:51', 'Sun 16:21', 'Sun 11:51', 'Sun 04:51', 'Sun 05:51', 'Sun 15:51', 'Sun 07:51', 'Sun 06:51', 'Sun 13:51', 'Sun 17:51', 'Sun 12:51', 'Sun 12:51', 'Sun 12:51', 'Sun 06:51', 'Sun 22:51', 'Sun 06:51', 'Sun 12:51', 'Sun 02:51', 'Sun 13:51', 'Sun 18:51', 'Sun 13:51', 'Sun 18:51', 'Sun 06:51', 'Sun 13:51', 'Sun 00:51', 'Sun 03:51', 'Sun 06:51', 'Sun 05:51', 'Sun 12:51', 'Sun 13:51', 'Sun 06:51', 'Sun 10:51', 'Sun 06:51', 'Sun 15:51', 'Sun 07:51', 'Sun 22:51', 'Sun 13:51', 'Sun 13:51', 'Sun 13:51', 'Sun 17:51', 'Sun 12:51', 'Sun 17:51', 'Sun 13:51', 'Sun 04:51', 'Sun 12:51', 'Sun 12:51', 'Sun 03:51', 'Sun 18:51', 'Sun 15:51', 'Sun 06:51', 'Sun 13:51', 'Sun 16:36', 'Sun 04:51', 'Sun 12:51', 'Sun 05:51', 'Sun 07:51', 'Sun 16:21', 'Sun 11:51', 'Sun 06:51', 'Sun 12:51', 'Mon 00:51', 'Sun 07:51', 'Sun 05:51', 'Sun 16:21', 'Sun 03:51', 'Sun 06:51', 'Sun 18:51', 'Sun 19:51', 'Sun 07:51', 'Sun 13:5
# ...

# %%
base_url = "https://www.timeanddate.com"
links = soup.find_all('td')
lst = []
for link in links:
    a_link = link.find('a', href=True)
    if a_link:
        full_link = base_url + a_link['href']
        lst.append(full_link)
print(lst)

    
#td_tags = soup.find_all('td')

# Şehir ve ülke isimlerini saklayacağımız listeler
#city_list = []
#country_list = []

#for td in td_tags:
#    a_tag = td.find('a', href=True)

#    if a_tag:
#        href = a_tag['href']  # href metni al
# Out:
# ['https://www.timeanddate.com/weather/ghana/accra', 'https://www.timeanddate.com/weather/ireland/dublin', 'https://www.timeanddate.com/weather/kenya/nairobi', 'https://www.timeanddate.com/weather/ethiopia/addis-ababa', 'https://www.timeanddate.com/weather/canada/edmonton', 'https://www.timeanddate.com/weather/bahamas/nassau', 'https://www.timeanddate.com/weather/australia/adelaide', 'https://www.timeanddate.com/weather/germany/frankfurt', 'https://www.timeanddate.com/weather/india/new-delhi', 'https://www.timeanddate.com/weather/algeria/algiers', 'https://www.timeanddate.com/weather/guatemala/guatemala', 'https://www.timeanddate.com/weather/usa/new-orleans', 'https://www.timeanddate.com/weather/kazakstan/almaty', 'https://www.timeanddate.com/weather/canada/halifax', 'https://www.timeanddate.com/weather/usa/new-york', 'https://www.timeanddate.com/weather/jordan/amman', 'https://www.timeanddate.com/weather/vietnam/hanoi', 'https://www.timeanddate.com/weather/norway/oslo', 'https://www.
# ...

# %%
# Out:
# Feels Like: 32 °C
# Wind Speed: 20 km/h
# Humidity: 74%
# Dew Point: 23 °C
# Visibility: 12 km
# Probability of Precipitation: 5%

# %%
lst
# Out:
# ['https://www.timeanddate.com/weather/ghana/accra',
#  'https://www.timeanddate.com/weather/ireland/dublin',
#  'https://www.timeanddate.com/weather/kenya/nairobi',
#  'https://www.timeanddate.com/weather/ethiopia/addis-ababa',
#  'https://www.timeanddate.com/weather/canada/edmonton',
#  'https://www.timeanddate.com/weather/bahamas/nassau',
#  'https://www.timeanddate.com/weather/australia/adelaide',
#  'https://www.timeanddate.com/weather/germany/frankfurt',
#  'https://www.timeanddate.com/weather/india/new-delhi',
#  'https://www.timeanddate.com/weather/algeria/algiers',
#  'https://www.timeanddate.com/weather/guatemala/guatemala',
#  'https://www.timeanddate.com/weather/usa/new-orleans',
#  'https://www.timeanddate.com/weather/kazakstan/almaty',
#  'https://www.timeanddate.com/weather/canada/halifax',
#  'https://www.timeanddate.com/weather/usa/new-york',
#  'https://www.timeanddate.com/weather/jordan/amman',
#  'https://www.timeanddate.com/weather/vietnam/hanoi',
# ...

# %%
labels = ['Feels Like', 'Wind Speed', 'Humidity', 'Dew Point', 'Visibility', 'Probability of Precipitation']

city_data = []

for idx, url in enumerate(lst, start=1):  
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    city_info = {"id": idx, "url": url}
    rows = soup.find_all('tr')
    
    for row in rows:
        th = row.find('th')
        if th and th.get_text().strip() in labels:
            td = row.find('td')
            if td:
                city_info[th.get_text().strip()] = td.get_text().strip()
    
    city_data.append(city_info)

for city in city_data:
    print(f"id: {city['id']}")
    print(f"URL: {city['url']}")
    for label in labels:
        print(f"{label}: {city.get(label, 'N/A')}")
    print("\n" + "-"*40 + "\n")
# Out:
# id: 1
# URL: https://www.timeanddate.com/weather/ghana/accra
# Feels Like: 30 °C
# Wind Speed: 16 km/h
# Humidity: 81%
# Dew Point: 23 °C
# Visibility: 9 km
# Probability of Precipitation: 32%
#
# ----------------------------------------
#
# id: 2
# URL: https://www.timeanddate.com/weather/ireland/dublin
# Feels Like: 14 °C
# Wind Speed: 15 km/h
# Humidity: 93%
# Dew Point: 13 °C
# Visibility: 5 km
# Probability of Precipitation: 27%
#
# ----------------------------------------
#
# id: 3
# URL: https://www.timeanddate.com/weather/kenya/nairobi
# Feels Like: 26 °C
# Wind Speed: 6 km/h
# Humidity: 40%
# Dew Point: 11 °C
# Visibility: 11 km
# Probability of Precipitation: 3%
#
# ----------------------------------------
#
# id: 4
# URL: https://www.timeanddate.com/weather/ethiopia/addis-ababa
# Feels Like: 20 °C
# Wind Speed: 29 km/h
# Humidity: 55%
# Dew Point: 10 °C
# Visibility: 12 km
# Probability of Precipitation: 31%
#
# ----------------------------------------
#
# id: 5
# ...

# %%
"""
def write_city_data_to_txt(city_data, filename="city_weather_data.txt"):
    with open(filename, 'w') as file:
        for city in city_data:
            file.write(f"id: {city['id']}\n")
            file.write(f"URL: {city['url']}\n")
            for label in ['Feels Like', 'Wind Speed', 'Humidity', 'Dew Point', 'Visibility', 'Probability of Precipitation']:
                file.write(f"{label}: {city.get(label, 'N/A')}\n")
            file.write("\n" + "-"*40 + "\n")
    print(f"Veriler '{filename}' dosyasına yazıldı.")


write_city_data_to_txt(city_data)
"""
# Out:
# '\ndef write_city_data_to_txt(city_data, filename="city_weather_data.txt"):\n    with open(filename, \'w\') as file:\n        for city in city_data:\n            file.write(f"id: {city[\'id\']}\n")\n            file.write(f"URL: {city[\'url\']}\n")\n            for label in [\'Feels Like\', \'Wind Speed\', \'Humidity\', \'Dew Point\', \'Visibility\', \'Probability of Precipitation\']:\n                file.write(f"{label}: {city.get(label, \'N/A\')}\n")\n            file.write("\n" + "-"*40 + "\n")\n    print(f"Veriler \'{filename}\' dosyasına yazıldı.")\n\n\nwrite_city_data_to_txt(city_data)\n'

# %%
'''
def write_data_to_txt(city_data, country_list, city_list, rbi_class, city_filename="city_weather_data.txt", country_filename="list_of_country.txt"):
    id = 1

    # Write city data
    with open(city_filename, 'w') as city_file:
        for city in city_data:
            city_file.write(f"id: {city['id']}\n")
            city_file.write(f"URL: {city['url']}\n")
            for label in ['Feels Like', 'Wind Speed', 'Humidity', 'Dew Point', 'Visibility', 'Probability of Precipitation']:
                city_file.write(f"{label}: {city.get(label, 'N/A')}\n")
            city_file.write("\n" + "-"*40 + "\n")
        print(f"City data written to '{city_filename}'")

    # Write country, city, and temp data
    
    with open(country_filename, 'w') as country_file:
        for country, city, temp in zip(country_list, city_list, rbi_class):
            country_file.write(f"id: {id}, Country: {country.title()}, City: {city.title()}, Temp: {temp}°C\n")
            id += 1
        print(f"Country data written to '{country_filename}'")
write_data_to_txt(city_data, country_list, city_list, rbi_class)
'''
# Out:
# '\ndef write_data_to_txt(city_data, country_list, city_list, rbi_class, city_filename="city_weather_data.txt", country_filename="list_of_country.txt"):\n    id = 1\n\n    # Write city data\n    with open(city_filename, \'w\') as city_file:\n        for city in city_data:\n            city_file.write(f"id: {city[\'id\']}\n")\n            city_file.write(f"URL: {city[\'url\']}\n")\n            for label in [\'Feels Like\', \'Wind Speed\', \'Humidity\', \'Dew Point\', \'Visibility\', \'Probability of Precipitation\']:\n                city_file.write(f"{label}: {city.get(label, \'N/A\')}\n")\n            city_file.write("\n" + "-"*40 + "\n")\n        print(f"City data written to \'{city_filename}\'")\n\n    # Write country, city, and temp data\n    \n    with open(country_filename, \'w\') as country_file:\n        for country, city, temp in zip(country_list, city_list, rbi_class):\n            country_file.write(f"id: {id}, Country: {country.title()}, City: {city.title()}, Temp: {temp}°
# ...

# %%
def write_data_with_dates(city_data, country_list, city_list, rbi_class, date_list, city_filename="city_weather_data.txt", country_filename="list_of_country.txt"):
    id = 1

    # Write city data
    with open(city_filename, 'w') as city_file:
        for city in city_data:
            city_file.write(f"id: {city['id']}\n")
            city_file.write(f"URL: {city['url']}\n")
            for label in ['Feels Like', 'Wind Speed', 'Humidity', 'Dew Point', 'Visibility', 'Probability of Precipitation']:
                city_file.write(f"{label}: {city.get(label, 'N/A')}\n")
            city_file.write("\n" + "-"*40 + "\n")
        print(f"City data written to '{city_filename}'")

    # Write country, city, temp, and date data
    with open(country_filename, 'w') as country_file:
        for country, city, temp, date in zip(country_list, city_list, rbi_class, date_list):
            country_file.write(f"id: {id}, Country: {country.title()}, City: {city.title()}, Temp: {temp}°C, Date: {date}\n")
            id += 1
        print(f"Country data with dates written to '{country_filename}'")
write_data_with_dates(city_data, country_list, city_list, rbi_class, date_list)
# Out:
# City data written to 'city_weather_data.txt'
# Country data with dates written to 'list_of_country.txt'

# %%
def move_files_to_folder(city_filename="city_weather_data.txt", country_filename="list_of_country.txt", folder_path="Data/txt_files"):
    # Eğer klasör yoksa, oluştur
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    try:
        # Dosyaları belirtilen klasöre taşı
        shutil.move(city_filename, os.path.join(folder_path, city_filename))
        shutil.move(country_filename, os.path.join(folder_path, country_filename))
        print(f"Files moved to '{folder_path}'")
    except FileNotFoundError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

move_files_to_folder()
# Out:
# Files moved to 'Data/txt_files'
